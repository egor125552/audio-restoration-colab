# %% [markdown]
# # Seed-VC в Google Colab
#
# Этот блокнот ставит закреплённую версию Seed-VC в отдельный Python 3.10, проверяет импорт и запускает реальный Gradio-интерфейс. Для разговорной речи по умолчанию запускается V2.
#
# Перед запуском выберите T4 GPU в настройках среды выполнения.

# %%
REPO = "https://github.com/egor125552/audio-restoration-colab.git"
DEST = "/content/audio-restoration-colab"
# !rm -rf $DEST
# !git clone --depth 1 --branch seed-vc-colab-smoke $REPO $DEST
INSTALL = f"{DEST}/seed_vc_colab/install_seed_vc.sh"
# !bash $INSTALL /content/seed-vc

# %% [markdown]
# ## Проверка установки
#
# Здесь модель не скачивает веса и ничего не генерирует. Проверяются реальные импорты Seed-VC и создание обоих Gradio-интерфейсов.

# %%
PYTHON = "/content/seed-vc/.venv/bin/python"
SMOKE = f"{DEST}/seed_vc_colab/smoke_import.py"
# !SEED_VC_HOME=/content/seed-vc $PYTHON $SMOKE

# %% [markdown]
# ## Запуск Seed-VC
#
# Ниже запускается настоящая V2. При первом запуске она скачает веса. После строки с публичной Gradio-ссылкой откройте её. Ячейка будет продолжать работать, пока интерфейс запущен.

# %%
import os

os.environ["SEED_VC_HOME"] = "/content/seed-vc"
LAUNCHER = f"{DEST}/seed_vc_colab/launch_colab.py"
# !SEED_VC_HOME=/content/seed-vc $PYTHON $LAUNCHER --version v2
